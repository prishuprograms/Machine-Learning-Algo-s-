# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.xlabel('Blood_Sugar_Level')
plt.ylabel('Frequency of patients')
plt.title('Blood_Sugar_Ratio')
blood_sugar_men  = [113, 85, 90, 150, 149, 88, 93, 115,135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.hist([blood_sugar_men,blood_sugar_women], bins =[80, 100,125,150], 
         rwidth = 0.95, color  = ['green' , 'red'] , label = ['men' , 'women'], orientation = 'horizontal')
plt.grid()
plt.legend()
